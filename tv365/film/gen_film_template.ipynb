# %%
import numpy as np
import g4f
from time import sleep
from fuzzywuzzy import fuzz
from glob import glob
from datasets import Dataset
import numpy as np
import pandas as pd
from pprint import pprint
import os
import json

# %%
g4f.Provider.GeekGpt
# Out:
# g4f.Provider.GeekGpt.GeekGpt

# %%
def sample_pool(n, pool):
    if n >= len(pool):
        return pool
    return list(np.random.choice(pool, size=n, replace=False))


def sample_seed(n, seed):
    return list(np.random.choice(seed, size=n, replace=False))


TEMPLATE1 = """Tôi đang xây dựng module tìm kiếm trong hệ thống TV trực tuyến chiếu các bộ phim. Tưởng tượng bạn là một người dùng ra lệnh cho hệ thống, hãy sinh ra các template người dùng thường nhập vào để tìm kiếm phim mà họ mong muốn.

Ý định của người dùng (user_intent) có thể là:
1) Mở trực tiếp phim (mo_phim)
2) Tìm phim (tim_phim)

Sau đây là một số ví dụ, hãy dựa vào các ví dụ này để xây dựng nhiều các template khác:
{templates}

"""
TEMPLATE2 = """Lưu ý: 
1) Các template cần đa dạng, không trùng lặp về mặt nội dung, mô tả đúng các tình huống thực tế của người dùng.
2) Chỉ trả về các template dưới dạng json: [{'template': 'your_template', 'intent':'user_intent'}, ...] không giải thích gì thêm."""


def get_response(examples):
    while True:
        try:
            templates = "\n".join(examples)
            prompt = TEMPLATE1.format(templates=templates) + TEMPLATE2
            response = g4f.ChatCompletion.create(
                provider=g4f.Provider.GeekGpt,
                model=g4f.models.gpt_4,
                messages=[{"role": "user", "content": prompt}],
            )
            return response
        except Exception as e:
            print(e)
            print("Request failed")
            sleep(5)


def extract_json(response):
    start = response.find("[")
    end = response.find("]") + 1
    if start == -1 or end == -1:
        return None
    try:
        return eval(response[start:end])
    except Exception as e:
        return None


def remove_duplicates(l, threshold=80):
    final = []
    for i in l:
        can_add = True
        for j in final:
            score = fuzz.ratio(i["template"], j["template"])
            if score >= threshold:
                can_add = False
                break
        if can_add:
            final.append(i)
    print(
        f"Removed {len(l) - len(final)} similar questions from total {len(l)} questions."
    )
    return final


def generate_questions(
    n_rounds=20,
    seed_path="./film_seed.txt",
    pool_path="./film_pool.txt",
    threshold=95,
    save_steps=5,
    n_seed=4,
    n_pool=6,
):
    for i in range(n_rounds):
        question_pool = []
        with open(pool_path, "r") as f:
            for line in f:
                question_pool.append(eval(line.strip())["template"])

        with open(seed_path, "r") as f:
            seed_tasks = f.read().splitlines()

        print(f"Round {i+1}")
        seed = sample_seed(n_seed, seed_tasks)
        pool = sample_pool(n_pool, question_pool)
        response = get_response(seed + pool)
        js = extract_json(response)
        if js is None:
            print("No json found")
            continue
        with open(pool_path, "a") as f:
            for q in js:
                f.write(str(q) + "\n")

        if (i + 1) % save_steps == 0:
            with open(pool_path, "r") as f:
                lines = f.read().splitlines()
                lines = [eval(line.strip()) for line in lines]
            lines = remove_duplicates(lines, threshold=threshold)

            with open(pool_path, "w") as f:
                for line in lines:
                    f.write(str(line) + "\n")

# %%
generate_questions(50)
# Out:
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Removed 77 similar questions from total 237 questions.
# Round 6
# Round 7
# Round 8
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 9
# Round 10
# Removed 45 similar questions from total 212 questions.
# Round 11
# Round 12
# Round 13
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 14
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 15
# Removed 45 similar questions from total 224 questions.
# Round 16
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 17
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 18
# Round 19
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 20
# 401 Client Error: Unauthorized for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Removed 50 similar questions from total 229 questions.
# Round 21
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 22
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 23
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 24
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 25
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Removed 40 similar questions from total 230 questions.
# Round 26
# Round 27
# Round 28
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 29
# Round 30
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 401 Client Error: Unauthorized for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Removed 42 similar questions from total 232 questions.
# Round 31
# Round 32
# Round 33
# Round 34
# Round 35
# Removed 42 similar questions from total 239 questions.
# Round 36
# Round 37
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 38
# Round 39
# Round 40
# Removed 45 similar questions from total 249 questions.
# Round 41
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 42
# Round 43
# Round 44
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 45
# Removed 47 similar questions from total 255 questions.
# Round 46
# Round 47
# Round 48
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 429 Client Error: Too Many Requests for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# 401 Client Error: Unauthorized for url: https://ai.fakeopen.com/v1/chat/completions
# Request failed
# Round 49
# Round 50
# Removed 50 similar questions from total 259 questions.
