# %%
from glob import glob
from datasets import Dataset, concatenate_datasets
import numpy as np
import pandas as pd
from pprint import pprint
import os
import json

# %%
ds = concatenate_datasets([Dataset.from_json(path) for path in glob('./tasks3/to_*.json')])
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
ds[0]
# Out:
# {'relevant_document': 'Mẹo trang điểm cho làn da khô và cách chăm sóc tóc đuôi ngựa là những điều mà phụ nữ cần biết. Bạn có thể thử các sản phẩm làm đẹp tự nhiên để giữ cho làn da mềm mại và tóc luôn mạnh mẽ. Tuy nhiên, những cách trang điểm cổ điển vẫn được nhiều người ưa chuộng. Hãy thử nghiệm những gam màu truyền thống để tạo nên vẻ đẹp quyến rũ. Đối với thời trang, váy dài và áo sơ mi vẫn là lựa chọn an toàn cho mọi dịp.',
#  'task': 'Tìm hiểu về những xu hướng và đổi mới trong ngành công nghiệp thời trang và làm đẹp.',
#  'positive_document': 'Trong năm nay, ngành công nghiệp thời trang và làm đẹp đã chứng kiến nhiều xu hướng mới đầy sáng tạo. Màu hồng phấn đã trở lại làm chủ đạo trong trang điểm, cùng với đó là kiểu tóc bob ngắn đang thu hút sự chú ý của giới trẻ. Trong thời trang, việc sử dụng vải tái chế và bền vững đang trở thành xu hướng quan trọng. Ngoài ra, phong cách vintage cũng đang tái xuất và gây ấn tượng mạnh mẽ.',
# ...

# %%
for x in ds:
  pprint(x)
  print('*-'*20)
# Out:
# {'positive_document': 'Trong năm nay, ngành công nghiệp thời trang và làm đẹp '
#                       'đã chứng kiến nhiều xu hướng mới đầy sáng tạo. Màu hồng '
#                       'phấn đã trở lại làm chủ đạo trong trang điểm, cùng với '
#                       'đó là kiểu tóc bob ngắn đang thu hút sự chú ý của giới '
#                       'trẻ. Trong thời trang, việc sử dụng vải tái chế và bền '
#                       'vững đang trở thành xu hướng quan trọng. Ngoài ra, '
#                       'phong cách vintage cũng đang tái xuất và gây ấn tượng '
#                       'mạnh mẽ.',
#  'relevant_document': 'Mẹo trang điểm cho làn da khô và cách chăm sóc tóc đuôi '
#                       'ngựa là những điều mà phụ nữ cần biết. Bạn có thể thử '
#                       'các sản phẩm làm đẹp tự nhiên để giữ cho làn da mềm mại '
#                       'và tóc luôn mạnh mẽ. Tuy nhiên, những cách trang điểm '
# ...
